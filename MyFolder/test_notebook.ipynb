# %%
# %sql
USE CATALOG dbx_catalog;
USE SCHEMA dbx_schema;
CREATE table employee
(ID int, name string, address string, salary int, bonus int )
using delta

# %%
# %sql
insert into dbx_catalog.dbx_schema.employee
values (100,'sri','pune',10000,100)

# %%
# %sql
select * from employee

# %%
# %sql
use catalog dbx_catalog;
use schema dbx_schema;
describe history employee

# %%
# %sql
select * from employee@v1

# %%
# %sql
restore table employee to version as of 1

# %%
# %sql
select * from employee

# %%
# %sql
insert into employee
values (101,'srikanth','pune',10100,100);
insert into employee
values (103,'ram','hyderabad',10100,100);

# %%
# %sql
describe detail employee

# %%
# %sql
optimize employee

# %%
# %sql
describe detail employee
